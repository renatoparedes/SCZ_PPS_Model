# %%
### Load PPS model
# %run ./PPS_SPQ_model.ipynb

# %%
### Load experimental data (Di Cosmo et al., 2017)

HCdata = pd.read_excel (r'PPS_data_SCZ_SPQ.xlsx',sheet_name='HC') 
SCZdata = pd.read_excel (r'PPS_data_SCZ_SPQ.xlsx',sheet_name='SCZ') 
SPQdata = pd.read_excel (r'PPS_data_SCZ_SPQ.xlsx',sheet_name='high spq') 
LSPQdata = pd.read_excel (r'PPS_data_SCZ_SPQ.xlsx',sheet_name='low spq') 

sets = [HCdata,SCZdata,SPQdata,LSPQdata]
RTdata = []

for i in sets:
    subjects = i['Subject'].unique()
    delays = i[(i['Sound']=='Loom')&(i['Cond'] != 'Loom_NO')]['Cond'].unique()
    delays = np.delete(delays,np.where(delays=='Loom_-700')[0])
    idx = [3,4,0,1,2]
    delays = delays[idx]
    RTs = []
    
    for s in subjects:
        meanRTs = []
        for t in delays:
            RT = i[(i['Subject'] == s)&(i['Cond'] == t)]['Rtpul']           
            meanRTs.append(np.mean(RT))
        RTs.append(meanRTs)
    RTdata.append(RTs)
    
HC_RTs = np.asarray(RTdata[0])
SCZ_RTs = np.asarray(RTdata[1])
SPQ_RTs = np.asarray(RTdata[2])
LSPQ_RTs = np.asarray(RTdata[3])

# %%
### Audio-tactile experiment simulation setup 

## Calculate distance in cms. Speaker is positioned at 100cm from the hand. 
times = np.asarray([300,800,1500,2200,2700])
timesweep = np.arange(300,2800,100)
ts = timesweep/1000
v = 30 #cm/s 
a_distances = (120 - ts*v) # distance points in cm (network coordinates)

## Simulation setup
simtime = 200 #ms 

## Synapses setup
Wt,Wa,Bt,Ba = Fw(6.5,6.5,2.5,2.5) 
bi = 0
pr = 0

# %%
## Lateral inputs

# Tactile area
def myLIt(z,Lt): # z is a matrix of MtxNt dimensions
    LI = np.zeros(Mt*Nt)
    z = np.reshape(z,(1,Mt*Nt))
    for i in range(Mt*Nt):
            LI[i] = np.sum(np.multiply(Lt[i,:],z[0,:])) 
    LI = np.reshape(LI,(Mt,Nt))
    return LI
# Auditory area
def myLIa(z,La): # z is a matrix of MaxNa dimensions
    LI = np.zeros(Ma*Na)
    z = np.reshape(z,(1,Ma*Na))
    for i in range(Ma*Na):
            LI[i] = np.sum(np.multiply(La[i,:],z[0,:])) 
    LI = np.reshape(LI,(Ma,Na))
    return LI


## Experiment function
def myexperimentrun(a_distances,time,b,pr,Lex,Lin,Sex,Sin):
    Lt,La = Lw(Lex,Lin,Sex,Sin,Lex,Lin,Sex*20,Sin*20)
    
    dt = 0.4
    timesteps = int(time/dt)
    ndist = len(a_distances)
    
    RTs = np.zeros(ndist)
    ZTs = np.zeros((Mt,Nt,ndist))
    ZAs = np.zeros((Ma,Na,ndist))
    
    ti = PHIt(0) 
    PrBa = prun(Ba,pr)
    PrWa = prun(Wa,pr*2.6)
    dtau = dt/tau
    
    qt = np.zeros((Mt,Nt,timesteps+1,ndist))
    ut = np.zeros((Mt,Nt,timesteps+1,ndist))
    zt = np.zeros((Mt,Nt,timesteps+1,ndist))
    pt = np.zeros((Mt,Nt,timesteps+1,ndist))

    qa = np.zeros((Ma,Na,timesteps+1,ndist))
    ua = np.zeros((Ma,Na,timesteps+1,ndist))
    za = np.zeros((Ma,Na,timesteps+1,ndist))
    pa = np.zeros((Ma,Na,timesteps+1,ndist))

    qm = np.zeros((timesteps+1,ndist))
    um = np.zeros((timesteps+1,ndist))
    zm = np.zeros((timesteps+1,ndist))
    pm = np.zeros((timesteps+1,ndist))
    
    ZT = np.zeros((1,timesteps+1,ndist))
    
    for d in range(ndist):
        xa_0 = a_distances[d] # How far the sound is presented.     
        ai = PHIa(0,xa_0) # Generates an auditory input

        for i in range(timesteps):    
            # Tactile activity
            ut[:,:,i+1,d] = ti+myLIt(zt[:,:,i,d],Lt)+bt(zm[i,d])
            qt[:,:,i+1,d] = qt[:,:,i,d] + dtau*(-qt[:,:,i,d]+ut[:,:,i,d])
            pt[:,:,i+1,d] = psit(qt[:,:,i,d],b)
            zt[:,:,i+1,d] = pt[:,:,i,d]*np.heaviside(pt[:,:,i,d],0)

            ZT[0,i+1,d] = np.sum(zt[:,:,i,d])

            # Auditory activity
            ua[:,:,i+1,d] = ai+myLIa(za[:,:,i,d],La)+ba(zm[i,d],PrBa) 
            qa[:,:,i+1,d] = qa[:,:,i,d] + dtau*(-qa[:,:,i,d]+ua[:,:,i,d])
            pa[:,:,i+1,d] = psia(qa[:,:,i,d],b)
            za[:,:,i+1,d] = pa[:,:,i,d]*np.heaviside(pa[:,:,i,d],0)

            # Multisensory activity
            um[i+1,d] = np.sum(np.multiply(Wt,zt[:,:,i,d])) + np.sum(np.multiply(PrWa,za[:,:,i,d]))
            qm[i+1,d] = qm[i,d] + dtau*(-qm[i,d]+um[i,d])
            pm[i+1,d] = psim(qm[i,d])
            zm[i+1,d] = pm[i,d]*np.heaviside(pm[i,d],0)    
        RT = np.argmax(zt[19,9,:,d]>0.9)*dt
    
        RTs[d] = RT
        ZMs = zm        
        ZTs[:,:,d] = zt[:,:,timesteps,d]
        ZAs[:,:,d] = za[:,:,timesteps,d]   
    return RTs,ZMs,ZTs,ZAs

# %%
idx = [0,5,12,19,24]
distances = np.take(a_distances,idx)
edata = np.mean(SPQ_RTs,axis=0)

def spqmodelrun(theta):
    spqRTs,ZMs,ZTs,ZAs = myexperimentrun(distances,simtime,bi,pr,theta[0],theta[1],theta[2],theta[3])
    yf = edata
    xf = spqRTs
    
    m = 4.751228589926564
    bias = 32.79217261352451
    
    cost = np.sum(np.square(np.divide(yf-(m*xf+bias),yf)))
    
    return cost*100000

bounds=[(0,1.5),(0,2.95),(0.01,1.25),(0.01,10)]
spqres = differential_evolution(spqmodelrun, bounds,disp=True)
# Out:
# differential_evolution step 1: f(x)= 309.918
# differential_evolution step 2: f(x)= 309.918
# differential_evolution step 3: f(x)= 280.428
# differential_evolution step 4: f(x)= 280.428
# differential_evolution step 5: f(x)= 271.243
# differential_evolution step 6: f(x)= 271.243
# differential_evolution step 7: f(x)= 271.243
# differential_evolution step 8: f(x)= 271.243
# differential_evolution step 9: f(x)= 271.243
# differential_evolution step 10: f(x)= 271.243
# differential_evolution step 11: f(x)= 271.243
# differential_evolution step 12: f(x)= 271.243
# differential_evolution step 13: f(x)= 271.243
# differential_evolution step 14: f(x)= 271.243
# differential_evolution step 15: f(x)= 271.243
# differential_evolution step 16: f(x)= 259.606
# differential_evolution step 17: f(x)= 259.606
# differential_evolution step 18: f(x)= 259.606
# differential_evolution step 19: f(x)= 259.606
# differential_evolution step 20: f(x)= 259.606
# differential_evolution step 21: f(x)= 259.606
# differential_evolution step 22: f(x)= 259.606
# differential_evolution step 23: f(x)= 259.606
# differential_evolution step 24: f(x)= 259.606
# differential_evolution step 25: f(x)= 259.606
# differential_evolution step 26: f(x)= 259.606
# differential_evolution step 27: f(x)= 259.606
# differential_evolution step 28: f(x)= 259.606
# differential_evolution step 29: f(x)= 259.606
# differential_evolution step 30: f(x)= 259.606
# differential_evolution step 31: f(x)= 259.606
# differential_evolution step 32: f(x)= 259.606
# differential_evolution step 33: f(x)= 259.606
# differential_evolution step 34: f(x)= 259.606
# differential_evolution step 35: f(x)= 259.606
# differential_evolution step 36: f(x)= 259.606
# differential_evolution step 37: f(x)= 259.606
# differential_evolution step 38: f(x)= 259.606
# differential_evolution step 39: f(x)= 259.606
# differential_evolution step 40: f(x)= 259.606
# differential_evolution step 41: f(x)= 259.606
# differential_evolution step 42: f(x)= 259.606
# differential_evolution step 43: f(x)= 259.606
# differential_evolution step 44: f(x)= 259.606
# differential_evolution step 45: f(x)= 259.606
# differential_evolution step 46: f(x)= 259.606
# differential_evolution step 47: f(x)= 259.606
# differential_evolution step 48: f(x)= 259.606
# differential_evolution step 49: f(x)= 259.606
# differential_evolution step 50: f(x)= 259.606
# differential_evolution step 51: f(x)= 259.606
# differential_evolution step 52: f(x)= 259.606
# differential_evolution step 53: f(x)= 259.606
# differential_evolution step 54: f(x)= 259.606
# differential_evolution step 55: f(x)= 259.606
# differential_evolution step 56: f(x)= 259.606
# differential_evolution step 57: f(x)= 259.606
# differential_evolution step 58: f(x)= 259.606
# differential_evolution step 59: f(x)= 259.606
# differential_evolution step 60: f(x)= 259.606
# differential_evolution step 61: f(x)= 259.606
# differential_evolution step 62: f(x)= 259.606
# differential_evolution step 63: f(x)= 259.606
# differential_evolution step 64: f(x)= 259.606
# differential_evolution step 65: f(x)= 259.606
# differential_evolution step 66: f(x)= 259.606
# differential_evolution step 67: f(x)= 259.606
# differential_evolution step 68: f(x)= 259.606
# differential_evolution step 69: f(x)= 259.606
# differential_evolution step 70: f(x)= 259.606
# differential_evolution step 71: f(x)= 259.606
# differential_evolution step 72: f(x)= 259.606
# differential_evolution step 73: f(x)= 259.606
# differential_evolution step 74: f(x)= 259.606
# differential_evolution step 75: f(x)= 259.606
# differential_evolution step 76: f(x)= 259.606
# differential_evolution step 77: f(x)= 259.606
# differential_evolution step 78: f(x)= 259.606
# differential_evolution step 79: f(x)= 259.606

# %%
print(spqres)
# Out:
#      fun: 259.6060687217393
#  message: 'Optimization terminated successfully.'
#     nfev: 4805
#      nit: 79
#  success: True
#        x: array([1.43151372, 0.01158904, 0.63291649, 2.94580086])

# %%
idx = [0,5,12,19,24]
distances = np.take(a_distances,idx)
edata = np.mean(SPQ_RTs,axis=0)
spqRTs,ZMs,ZTs,ZAs = myexperimentrun(distances,simtime,0,0,1.43151372, 0.01158904, 0.63291649, 2.94580086)

# %%
xf = spqRTs
yf = edata    
m = (xf.size * np.sum(xf*yf) - np.sum(xf) * np.sum(yf)) / (xf.size*np.sum(xf*xf) - np.sum(xf) ** 2)
bias = (np.sum(yf) - m*np.sum(xf)) / xf.size

plt.figure(1)
plt.scatter(distances,m*spqRTs+bias,label = 'H-SPQ Model')
plt.scatter(distances,edata,label = 'H-SPQ Data')
plt.legend()

# %%
spqres = np.asarray([m*xf+bias,yf])
np.save('spqrescopy.npy', spqres)

# %%
evdis = 4

plt.figure(2)
plt.imshow(ZTs[:,:,evdis].transpose());

plt.figure(3)
plt.imshow(ZAs[:,:,evdis].transpose());

plt.figure(4)
plt.plot(ZMs);

# %%
Lt,Lv = Lw(1.24393855, 0.03612983, 1.17230347, 8.16940845, 1.24393855, 0.03612983, 1.17230347*20, 8.16940845*20)

# %%
fig, (ax1,ax2) = plt.subplots(1,2,sharex=True,figsize=(12,4));
fig.subplots_adjust(wspace = 0.75, hspace = 0.5)

ax1 = plt.subplot(121)
im1 = ax1.imshow(Lt)
ax1.set_xlabel('Neuron number',size=16)
ax1.set_ylabel('Neuron number',size=16)
divider = make_axes_locatable(plt.gca())
cax = divider.append_axes("right", "5%", pad="3%")
cbar = fig.colorbar(im1,cax=cax)
cbar.ax.get_yaxis().labelpad = 12
cbar.ax.set_ylabel('L\u1D57', rotation=270,size=18)
ax1.text(-0.1, 1.1, string.ascii_uppercase[0], transform=ax1.transAxes, 
            size=20, weight='bold')

ax2 = plt.subplot(122)
im2 = ax2.imshow(Lv)
plt.xlabel('Neuron number',size=16)
plt.ylabel('Neuron number',size=16)
#ax2.set_xticks(np.arange(-.5, 61, 10))
#ax2.set_yticks(np.arange(-.5, 61, 10))
#ax2.set_xticklabels(np.arange(0, 61, 10))
#ax2.set_yticklabels(np.arange(0, 61, 10))
divider = make_axes_locatable(plt.gca())
cax = divider.append_axes("right", "5%", pad="3%")
cbar = fig.colorbar(im2,cax=cax)
cbar.ax.get_yaxis().labelpad = 12
cbar.ax.set_ylabel('L\u1D5B', rotation=270,size=18)
ax2.text(-0.1, 1.1, string.ascii_uppercase[1], transform=ax2.transAxes, 
            size=20, weight='bold')

fig.subplots_adjust(wspace=.25)

plt.savefig('spqrecsynapses.png', bbox_inches='tight')

# %%
print(spqRTs)
print(m,bias)
# Out:
# [62.8 60.4 56.8 53.2 52. ]
# 6.257714922190927 -52.07271333312569
